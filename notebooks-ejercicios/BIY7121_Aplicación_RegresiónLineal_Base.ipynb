# %% [markdown]
# # Ejercicio - Regresión lineal
#
# **Autor:** Jazna Meza Hidalgo
#
# **Correo Electrónico:** ja.meza@profesor.duoc.cl
#
# **Fecha de Creación:** Abril de 2025
#
# **Versión:** 1.0
#
# ---
#
# ## Descripción
#
# Este notebook está destinado a ressolver el primer modelo de predicción sobre una variable continua.
# ---

# %% [markdown]
# # Descripción de la data

# %% [markdown]
# ---
#
# Trabajaremos con **tips**, un dataset muy conocido en la academia
#
# Las características o features son las siguientes:
#
#
# *   Total_bill: Total de la cuenta
# *   Tip: Propina
# *   Sex: Género del mesero
# *   Smoker: Dato para diferenciar una mesa de fumador versus una de no fumador.
# *   Day: Qué día de la semana fue la atención.
# *   Time: En que horario, si fue almuerzo o cena.
# *   Size: Tamaño de la mesa.

# %% [markdown]
# # Negocio
#
# Este conjunto de datos proporciona una oportunidad para realizar análisis exploratorio y modelado predictivo para comprender mejor los factores que influyen en la cantidad de propina que los clientes dejan en un restaurante. Algunos posibles contextos de negocio para este conjunto de datos podrían incluir:
#
# **Análisis de tendencias de propinas**: Un restaurante podría utilizar este conjunto de datos para analizar las tendencias históricas de propinas y comprender cómo varían según el día de la semana, la hora del día, el tamaño del grupo y otros factores.
#
# **Segmentación de clientes**: Los restaurantes podrían utilizar la información sobre el género, el hábito de fumar y otros datos demográficos para segmentar a sus clientes y personalizar sus estrategias de servicio y marketing.
#
# **Predicción de propinas**: Utilizando técnicas de modelado predictivo, como la regresión, un restaurante podría desarrollar un modelo para predecir la cantidad de propina que es probable que deje un cliente en función de ciertas características, lo que podría ayudar a optimizar la asignación de personal y mejorar la satisfacción del cliente.

# %% [markdown]
# # Requerimientos
#
# + ¿En cuál de los contextos de negocio mencionados anteriormente podría aplicar lo aprendido hasta el momento en la asignatura?
# + Realizar un análisis exploratorio que le ayude a descubrir tendencias.
# + Predecir el valor de la propina. Usted debe elegir las variables independientes que va a considerar

# %% [markdown]
# # Carga de librerias

# %%
from seaborn import load_dataset

# %% [markdown]
# # Carga la data

# %%
# Carga el dataset de tips para comenzar a trabajar
tips = load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)
